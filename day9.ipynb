# %%
import smtplib

# %%
import ssl

# %%
from email.message import EmailMessage

# %%
EMAIL = "1.agarwal@gmail.com"
APP_PASSWORD= "pass"
RECEIVER ="nihar29@gmail.com"

# %%
msg = EmailMessage()

# %%
msg["From"] = EMAIL
msg["To"] = RECEIVER
msg["Subject"] = "HELLO THIS IS PY..."

# %%
msg.set_content("this email was shared by python code...")

# %%
context = ssl.create_default_context()

# %%
with smtplib.SMTP_SSL("wal@gmail.com", 123 ,context=context) as server:
    server.login(EMAIL,APP_PASSWORD)
    server.send_message(msg)

# %%
import smtplib
import ssl
from email.message import EmailMessage
EMAIL = "arwal@gmail.com"
APP_PASSWORD= "pass"
RECEIVER ="na@gmail.com"
msg = EmailMessage()
msg["From"] = EMAIL
msg["To"] = RECEIVER
msg["Subject"] = "HELLO THIS IS PY..."
msg.set_content("this email was shared by python code...")
context = ssl.create_default_context()
with smtplib.SMTP_SSL("ram01.agarwal@gmail.com", 465, context=context) as server:
    server.login(EMAIL,APP_PASSWORD)
    server.send_message(msg)

# %%
import smtplib
import ssl
from email.message import EmailMessage
EMAIL = "rwal@gmail.com"
APP_PASSWORD= "pass"
RECEIVER ="@gmail.com"
msg = EmailMessage()
msg["From"] = EMAIL
msg["To"] = RECEIVER
msg["Subject"] = "HELLO THIS IS PY..."
msg.set_content("this email was shared by python code...")
context = ssl.create_default_context()
with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
    server.login(EMAIL,APP_PASSWORD)
    server.send_message(msg)

# %%
#twilio

# %%
from twilio.rest import Client
ACCOUNT_SID ="sid"
AUTH_TOKEN = "token"

# %%
TWILIO_NUMMER= "+no"

# %%
RECIVER_NUMBER= "+"

# %%
Client= Client(ACCOUNT_SID, AUTH_TOKEN)

# %%
message = Client.messages.create(body ="hello i am ram", from_= TWILIO_NUMBER,to= RECIVER_NUMBER )
