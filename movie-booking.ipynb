# %%
import pyttsx3
speaker = pyttsx3.init()
speaker.say("welcome honey paaji")
speaker.runAndWait()

# %%
age = int (input("Enter your age : " ))
ticket = input ("Enter 0 for True  and 1 for False")
flag = bool(ticket)
if age > 18: 
    print ("you can watch the movie")
    if ticket == True :
        print ("you can go inside")
elif age < 15:
    print ("you can watch the movie with your parents")
else:
    print ("not allowed")
# Out:
# Enter your age :  25
# Enter 0 for True  and 1 for False 1
# you can watch the movie
