# %%
a="*"

for i in range (5,0,-1):
    
    print(a *i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
a= int (input("enter a no."))

if a==0:
       print ("zero")

elif a<0:
        print ("negative")
elif a>0:
        print("positive")
# Out:
# enter a no. 5
# positive
