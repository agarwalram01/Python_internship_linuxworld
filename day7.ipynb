# %%
import http.server

# %%
import socketserver

# %%
PORT = 8000

# %%
handler = http.server.SimpleHTTPRequestHandler

# %%
with socketserver.TCPServer(("", PORT ), handler) as http:
    print("server running on port",PORT)
    http.serve_forever()
# Out:
# server running on port 8000
# 10.72.107.54 - - [24/Nov/2025 11:42:16] "GET / HTTP/1.1" 200 -
# 10.72.107.54 - - [24/Nov/2025 11:42:25] "GET /rede%20hat%20acc.png HTTP/1.1" 200 -
# 10.72.107.31 - - [24/Nov/2025 11:42:47] "GET / HTTP/1.1" 200 -
# 10.72.107.31 - - [24/Nov/2025 11:42:52] "GET /rede%20hat%20acc.png HTTP/1.1" 200 -

# %%
# http://10.72.107.54:8000

# %%
#notepad mydashboard.py
#streamlit run mydashboard1.py

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

st.title("Streamlit app of vgu")
st.text("Welcome to our dashboard")
st.header("I am a header")
st.write("You can Write", 10+5)

name = st.text_input("Enter your name: ")
age = st.number_input("Enter your age: ")
st.write("Your name is:", name , "Your age is: ", age)
st.selectbox("Enter your course: ", ["BCA", "BTECH", "MCA"])
if st.button("Click ME"):
    st.success("Clicked Button")
file = st.file_uploader("Upload your file")
if file:
    content = file.read()
    st.write("File Uploaded Successfully")

data = {"Name":["TOM","Jack", "Pop", "Harry"], "Marks" : [10,20,20,10]}
df = pd.DataFrame(data)

st.dataframe(df)

data = pd.DataFrame({
    "Marks" : [10,20,20,10]
 
})
st.line_chart(data)
st.bar_chart(data)

subject = ["Python", "C++", "Java"]
marks = [20,10,5]

fig , ax = plt.subplots()
ax.pie(marks, labels=subject,autopct='%1.1f%%')
st.pyplot(fig)
# Out:
# 2025-11-24 14:41:25.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 14:41:25.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import streamlit as st

with st.sidebar:
    st.header('Settings Panel')
    # Ab iske andar ke saare items sidebar mein dikhenge
    option = st.selectbox(
        'Kaunsa option chunenge?',
        ('Option 1', 'Option 2', 'Option 3')
    )
    st.write('Chuna gaya option:', option)

st.write('Yeh text main page par dikhega.')
# Out:
# 2025-11-24 15:09:24.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 15:09:24.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
