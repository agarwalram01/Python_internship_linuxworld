# %%
mylist = ["apple","banana","orange"] 
type(mylist)
# Out:
# list

# %%
print(mylist[0])
# Out:
# apple

# %%
print(mylist[1:2])
# Out:
# ['banana']

# %%
print(mylist[1:])
# Out:
# ['banana', 'orange']

# %%
mylist.append("cherry")

# %%
print(mylist)
# Out:
# ['apple', 'banana', 'orange', 'cherry', 'cherry', 'cherry', 'cherry']

# %%
mylist.insert(1,"blueberry")

# %%
print(mylist)
# Out:
# ['apple', 'blueberry', 'banana', 'orange', 'cherry', 'cherry', 'cherry', 'cherry']

# %%
mylist.sort()

# %%
print(mylist)
# Out:
# ['apple', 'banana', 'blueberry', 'cherry', 'cherry', 'cherry', 'cherry', 'orange']

# %%
mylist.count("cherry")
# Out:
# 4

# %%
mylist.pop()
# Out:
# 'orange'

# %%
print(mylist)
# Out:
# ['apple', 'banana', 'blueberry', 'cherry', 'cherry', 'cherry', 'cherry']

# %%
mylist.remove("cherry")

# %%
print(mylist)
# Out:
# ['apple', 'banana', 'blueberry', 'cherry', 'cherry', 'cherry']

# %%
mylist.clear()

# %%
print(mylist)
# Out:
# []

# %%
mylist = ["apple","banana","orange"]

# %%
print(mylist)
# Out:
# ['apple', 'banana', 'orange']

# %%
mytuple = ("1","2","3","4","5")

# %%
print(mytuple)
# Out:
# ('1', '2', '3', '4', '5')

# %%
mytuple.index("1")
# Out:
# 0

# %%
SET

# %% [raw]
# list[] v/s tuple() set{}

# %%
setmy={1,2,3,4,5,6,6,7,4,3}

# %%
print(setmy)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set1 = {1,3}
set2 = {3,4}

# %%
print(set1|set2) #union
# Out:
# {1, 3, 4}

# %%
print(set1&set2) #intersection
# Out:
# {3}

# %%
set1.union(set2)
# Out:
# {1, 3, 4}

# %%
set1.clear()

# %%
SAT

# %%
DICTIONARY

# %%
student = {"name":"ram" , "age":"20"}

# %%
student.pop("name")
# Out:
# 'ram'

# %%
print(student)
# Out:
# {'age': '20'}

# %%
student = {"name":"Tom","age":18}
student.values()
# Out:
# dict_values(['Tom', 18])

# %%
text = "Hello VGU"

# %%
print(text[0:5])
# Out:
# Hello

# %%
print(text.find("VGU"))
# Out:
# 6

# %%
print(text.replace("VGU" , "VGU GUYS"))
# Out:
# Hello VGU GUYS

# %%
text = "HELLO VGU"
print(text.split())
# Out:
# ['HELLO', 'VGU']

# %%
text2 = ['HELLO','VGU']

# %%
print(text2)
# Out:
# ['HELLO', 'VGU']

# %%
print(" ".join(text2))
# Out:
# HELLO VGU
