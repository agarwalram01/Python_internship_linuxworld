# %%
# Install necessary libraries
# !pip install gTTS SpeechRecognition pyaudio

# %%
from gtts import gTTS
from IPython.display import Audio


text = "Hello! This is a simple text to speech demonstration."


tts = gTTS(text=text, lang='en')


tts.save("speech.mp3")
print("Audio saved as 'speech.mp3'")


Audio("speech.mp3")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from gtts import gTTS
#       2 from IPython.display import Audio
#       5 text = "Hello! This is a simple text to speech demonstration."
#
# ModuleNotFoundError: No module named 'gtts'

# %%
import speech_recognition as sr

# 1. Initialize the recognizer
recognizer = sr.Recognizer()

# 2. Use the microphone as source
try:
    with sr.Microphone() as source:
        print("Please speak something...")
        
        # Adjust for ambient noise
        recognizer.adjust_for_ambient_noise(source)
        
        # Listen to the audio
        audio = recognizer.listen(source)
        print("Processing...")
        
        # 3. Recognize speech using Google Speech Recognition
        text = recognizer.recognize_google(audio)
        print("You said:", text)
        
except sr.UnknownValueError:
    print("Sorry, I could not understand the audio.")
except sr.RequestError:
    print("Could not request results from Google Speech Recognition service.")
except Exception as e:
    print(f"Error: {e}")
