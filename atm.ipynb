# %%
balance = 50000
pin = 2005
attempts = 0   

while True:
    user_pin = int(input("Enter your PIN: "))

    if user_pin == pin:
        attempts = 0  
        print("Your balance is:", balance)

        amount = int(input("Enter amount to withdraw: "))

        if amount <= balance:
            balance -= amount
            print("Amount withdrawn successfully!")
            print("New balance is:", balance)
        else:
            print("Insufficient balance!")

    else:
        attempts += 1
        print("Wrong PIN! Attempts:", attempts)

        if attempts >= 3:
            print(" Too many wrong attempts! Your account is blocked.")
            break
# Out:
# Enter your PIN:  1254
# Wrong PIN! Attempts: 1
# Enter your PIN:  1548
# Wrong PIN! Attempts: 2
# Enter your PIN:  1234
# Your balance is: 5000
# Enter amount to withdraw:  4826
# Amount withdrawn successfully!
# New balance is: 174
# Enter your PIN:  1234
# Your balance is: 174
# Enter amount to withdraw:  500
# Insufficient balance!
